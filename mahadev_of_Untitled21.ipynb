# %% [markdown]
# <a href="https://colab.research.google.com/github/khushi947/CODSOFT/blob/main/mahadev_of_Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML

HTML("""
<div style="
  width:380px;
  background: radial-gradient(ellipse at center, #1a0533 0%, #0d0221 40%, #000 100%);
  padding: 30px 20px;
  text-align: center;
  position: relative;
  overflow: hidden;
  border-radius: 12px;
  margin: auto;
">

<!-- STARS -->
<canvas id="c" style="position:absolute;top:0;left:0;width:100%;height:100%;"></canvas>

<!-- GALAXY GLOW -->
<div style="position:absolute;top:60px;left:50%;transform:translateX(-50%);
  width:300px;height:300px;
  background:radial-gradient(ellipse, rgba(138,43,226,0.3) 0%, rgba(0,100,255,0.15) 40%, transparent 70%);
  border-radius:50%;"></div>

<!-- MOON -->
<div style="position:relative;z-index:2;margin-bottom:-10px;">
  <div style="
    width:60px;height:60px;
    background:transparent;
    border:6px solid #e0e0e0;
    border-radius:50%;
    clip-path:polygon(0 0,70% 0,70% 100%,0 100%);
    margin:0 auto;
    box-shadow:0 0 20px rgba(255,255,255,0.5);
  "></div>
</div>

<!-- TRISHUL -->
<div style="position:relative;z-index:2;display:flex;flex-direction:column;align-items:center;margin-bottom:-5px;">
  <div style="display:flex;gap:10px;align-items:flex-end;">
    <div style="display:flex;flex-direction:column;align-items:center;">
      <div style="width:8px;height:40px;background:linear-gradient(180deg,#64b5f6,#1565c0);border-radius:4px 4px 0 0;box-shadow:0 0 10px #64b5f6;"></div>
    </div>
    <div style="display:flex;flex-direction:column;align-items:center;">
      <div style="width:10px;height:60px;background:linear-gradient(180deg,#90caf9,#1565c0);border-radius:5px 5px 0 0;box-shadow:0 0 15px #90caf9;"></div>
    </div>
    <div style="display:flex;flex-direction:column;align-items:center;">
      <div style="width:8px;height:40px;background:linear-gradient(180deg,#64b5f6,#1565c0);border-radius:4px 4px 0 0;box-shadow:0 0 10px #64b5f6;"></div>
    </div>
  </div>
  <div style="width:60px;height:5px;background:linear-gradient(90deg,#1565c0,#90caf9,#1565c0);border-radius:3px;box-shadow:0 0 10px #64b5f6;"></div>
  <div style="width:6px;height:80px;background:linear-gradient(180deg,#90caf9,#1565c0);box-shadow:0 0 10px #64b5f6;"></div>
</div>

<!-- SHIVLING -->
<div style="position:relative;z-index:2;display:flex;flex-direction:column;align-items:center;">
  <!-- Shivling top -->
  <div style="
    width:120px;height:160px;
    background:radial-gradient(ellipse at 35% 30%, #546e7a, #263238, #1a1a1a);
    border-radius:50% 50% 20% 20%;
    position:relative;
    box-shadow: 0 0 30px rgba(100,181,246,0.3), inset -10px -10px 30px rgba(0,0,0,0.5);
  ">
    <!-- OM symbol -->
    <div style="
      position:absolute;top:30px;left:50%;transform:translateX(-50%);
      font-size:28px;color:#ffd700;
      text-shadow:0 0 15px rgba(255,215,0,0.8);
      font-family:serif;
    ">ॐ</div>
    <!-- 3 white lines (tripund) -->
    <div style="position:absolute;top:65px;left:50%;transform:translateX(-50%);display:flex;flex-direction:column;gap:5px;align-items:center;">
      <div style="width:50px;height:4px;background:white;border-radius:2px;opacity:0.9;"></div>
      <div style="width:50px;height:4px;background:white;border-radius:2px;opacity:0.9;"></div>
      <div style="width:50px;height:4px;background:white;border-radius:2px;opacity:0.9;"></div>
    </div>
    <!-- Red bindi -->
    <div style="position:absolute;top:62px;left:50%;transform:translateX(-50%);
      width:10px;height:18px;background:radial-gradient(#ff1744,#b71c1c);border-radius:50%;
      box-shadow:0 0 8px rgba(255,23,68,0.8);"></div>
  </div>
  <!-- Shivling base (Argha/Panapatta) -->
  <div style="
    width:160px;height:30px;
    background:linear-gradient(180deg,#455a64,#263238);
    border-radius:8px;
    box-shadow:0 5px 15px rgba(0,0,0,0.5);
    position:relative;
  ">
    <!-- Decorative lines -->
    <div style="position:absolute;top:8px;left:10px;right:10px;height:2px;background:rgba(255,215,0,0.4);border-radius:1px;"></div>
    <div style="position:absolute;top:16px;left:10px;right:10px;height:2px;background:rgba(255,215,0,0.4);border-radius:1px;"></div>
  </div>
  <div style="
    width:200px;height:20px;
    background:linear-gradient(180deg,#37474f,#1c313a);
    border-radius:5px;
    box-shadow:0 5px 15px rgba(0,0,0,0.5);
  "></div>
</div>

<!-- NANDI (Bull) -->
<div style="position:relative;z-index:2;display:flex;justify-content:center;margin-top:-10px;">
  <!-- Body -->
  <div style="position:relative;">
    <div style="
      width:140px;height:70px;
      background:radial-gradient(ellipse at 40% 35%, #546e7a, #263238);
      border-radius:40% 40% 30% 30%;
      position:relative;
      box-shadow:0 0 20px rgba(0,0,0,0.5);
    ">
      <!-- Head -->
      <div style="
        position:absolute;top:-30px;left:10px;
        width:55px;height:50px;
        background:radial-gradient(ellipse at 40% 35%, #607d8b, #263238);
        border-radius:40% 40% 35% 35%;
      ">
        <!-- Horns -->
        <div style="position:absolute;top:-20px;left:3px;width:8px;height:25px;background:linear-gradient(180deg,#ffd700,#f57f17);border-radius:4px;transform:rotate(-15deg);"></div>
        <div style="position:absolute;top:-20px;right:3px;width:8px;height:25px;background:linear-gradient(180deg,#ffd700,#f57f17);border-radius:4px;transform:rotate(15deg);"></div>
        <!-- Eye -->
        <div style="position:absolute;top:20px;left:12px;width:8px;height:8px;background:#1a1a1a;border-radius:50;border:1px solid #90a4ae;"></div>
        <!-- Nose ring -->
        <div style="position:absolute;bottom:5px;left:50%;transform:translateX(-50%);width:14px;height:8px;border:2px solid #ffd700;border-radius:50%;border-bottom:none;"></div>
      </div>
      <!-- Necklace -->
      <div style="position:absolute;top:5px;left:50%;transform:translateX(-50%);display:flex;gap:3px;">
        <div style="width:6px;height:6px;background:radial-gradient(#ffd700,#f57f17);border-radius:50%;"></div>
        <div style="width:6px;height:6px;background:radial-gradient(#ffd700,#f57f17);border-radius:50%;"></div>
        <div style="width:6px;height:6px;background:radial-gradient(#ffd700,#f57f17);border-radius:50%;"></div>
        <div style="width:6px;height:6px;background:radial-gradient(#ffd700,#f57f17);border-radius:50%;"></div>
        <div style="width:6px;height:6px;background:radial-gradient(#ffd700,#f57f17);border-radius:50%;"></div>
      </div>
      <!-- Legs -->
      <div style="position:absolute;bottom:-25px;left:15px;display:flex;gap:12px;">
        <div style="width:14px;height:28px;background:#37474f;border-radius:4px 4px 6px 6px;"></div>
        <div style="width:14px;height:28px;background:#37474f;border-radius:4px 4px 6px 6px;"></div>
        <div style="width:14px;height:28px;background:#37474f;border-radius:4px 4px 6px 6px;"></div>
        <div style="width:14px;height:22px;background:#37474f;border-radius:4px 4px 6px 6px;"></div>
      </div>
    </div>
  </div>
</div>

<!-- TEXT -->
<div style="margin-top:35px;position:relative;z-index:2;">
  <div style="font-size:26px;color:#ffd700;letter-spacing:4px;font-family:serif;
    text-shadow:0 0 20px rgba(255,215,0,0.9);">🔱 हर हर महादेव 🔱</div>
  <div style="font-size:13px;color:rgba(255,255,255,0.5);letter-spacing:3px;margin-top:8px;">
    JAI BHOLENATH</div>
</div>

</div>

<script>
// Stars canvas
const canvas = document.getElementById('c');
const ctx = canvas.getContext('2d');
canvas.width = 380; canvas.height = 700;
for(let i=0;i<200;i++){
  const x=Math.random()*380, y=Math.random()*700;
  const r=Math.random()*1.5;
  ctx.beginPath();
  ctx.arc(x,y,r,0,Math.PI*2);
  ctx.fillStyle=`rgba(255,255,255,${Math.random()*0.8+0.2})`;
  ctx.fill();
}
</script>
""")
# Out:
# <div style="
#   width:380px;
#   background: radial-gradient(ellipse at center, #1a0533 0%, #0d0221 40%, #000 100%);
#   padding: 30px 20px;
#   text-align: center;
#   position: relative;
#   overflow: hidden;
#   border-radius: 12px;
#   margin: auto;
# ">
#
# <!-- STARS -->
# <canvas id="c" style="position:absolute;top:0;left:0;width:100%;height:100%;"></canvas>
#
# <!-- GALAXY GLOW -->
# <div style="position:absolute;top:60px;left:50%;transform:translateX(-50%);
#   width:300px;height:300px;
#   background:radial-gradient(ellipse, rgba(138,43,226,0.3) 0%, rgba(0,100,255,0.15) 40%, transparent 70%);
#   border-radius:50%;"></div>
#
# <!-- MOON -->
# <div style="position:relative;z-index:2;margin-bottom:-10px;">
#   <div style="
#     width:60px;height:60px;
#     background:transparent;
#     border:6px solid #e0e0e0;
#     border-radius:50%;
#     clip-path:polygon(0 0,70% 0,70% 100%,0 100%);
#     margin:0 auto;
#     box-shadow:0 0 20px rgba(255,255,255,0.5);
#   "></div>
# ...
